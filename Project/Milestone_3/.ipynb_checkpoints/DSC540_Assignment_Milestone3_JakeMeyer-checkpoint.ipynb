# %% [markdown]
# # DCS 540 Data Preparation (DSC540-T301 2225-1)
# ## Bellevue University
# ## Project: Milestone 3
# ## Author: Jake Meyer
# ## Date: 05/08/2022

# %% [markdown]
# ## Milestone 3: Website Data Cleaning
# Website source listed below:
#
# [Data Scientist Salary Data from Zippia](https://www.zippia.com/data-scientist-jobs/salary/#by-industry)

# %%
'''
Import the necessary libraries to transform and/or clean the website data from Zippia.
''' 
# !pip install tabula-py xlrd lxml

# !pip install openpyxl

import numpy as np

import pandas as pd
   
from bs4 import BeautifulSoup

import requests

import html5lib
# Out:
# Requirement already satisfied: tabula-py in c:\users\jkmey\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: xlrd in c:\users\jkmey\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: lxml in c:\users\jkmey\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: numpy in c:\users\jkmey\anaconda3\lib\site-packages (from tabula-py) (1.20.3)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\jkmey\anaconda3\lib\site-packages (from tabula-py) (1.3.4)
# Requirement already satisfied: distro in c:\users\jkmey\anaconda3\lib\site-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jkmey\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jkmey\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jkmey\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\jkmey\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\jkmey\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
'''
Create a request to the zippia website and store as source.
Read the website content with BeautifulSoup().
'''
source = requests.get('https://www.zippia.com/data-scientist-jobs/salary').text
soup = BeautifulSoup(source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="/ui-router/images/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link data-href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700|Roboto:300,400,500,700&amp;display=swap" rel="stylesheet"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <meta content="height=device-height,  width=device-width, initial-scale=1.0,  minimum-scale=1.0, maximum-scale=1.0,  user-scalable=no, target-densitydpi=device-dpi, viewport-fit=cover" name="viewport"/>
#   <title>
#    Data Scientist Salary (April 2022) - Zippia | Average Data Scientist Salaries Hourly And Annual
#   </title>
#   <meta content="The average salary for &lt;jobTitleArticle&gt; Data Scientist is $102,000 per year, or $49.39 per hour in United States. Find out the average by state, years of experience, field. Data Scientist gender pay gap, race wage gap and income by education level." name="description"/>
#   <meta content="" name="author"/>
#   <meta content="Data Scientist Salary (April 2022) - Zippia | Average Data Scientist Salaries Hourly And Annual" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.zippia.com/data-scientist-jobs/salary/" property="og:url"/>
#   <meta content="The average salary for &lt;jobTitleArticle&gt; Data Scientist is $102,000 per year, or $49.39 per hour in United States. Find out the average by state, years of experience, field. Data Scientist gender pay gap, race wage gap and income by education level." property="og:description"/>
#   <meta content="2020-05-18T00:00:00-08:00" property="article:published_time"/>
#   <meta content="2022-02-09T02:00:00-08:00" property="article:modified_time"/>
#   <meta content="2022-02-09T02:00:00-08:00" property="og:updated_time"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@ZippiaInc" name="twitter:site"/>
#   <meta content="Data Scientist Salary (April 2022) - Zippia | Average Data Scientist Salaries Hourly And Annual" name="twitter:title"/>
#   <meta content="https://www.zippia.com/data-scientist-jobs/salary/" name="twitter:url"/>
#   <meta content="The average salary for &lt;jobTitleArticle&gt; Data Scientist is $102,000 per year, or $49.39 per hour in United States. Find out the average by state, years of experience, field. Data Scientist gender pay gap, race wage gap and income by education level." name="twitter:description"/>
#   <meta charset="utf-8"/>
#   <meta content="https://static.zippia.com/assets/zippia-og-image.png" name="twitter:image:src"/>
#   <meta content="508633732650088" property="fb:app_id"/>
#   <meta content="https://static.zippia.com/assets/zippia-og-image.png" property="og:image"/>
#   <link href="https://www.zippia.com/data-scientist-jobs/salary/" rel="canonical"/>
#   <script>
#    var pageCategory = 'Career Salary Page';
#   </script>
#   <script>
#    var userGroup = 'majorSalarySections.groupC+jobSearchSituation.groupA+bcpShowTestCategories.groupA+cmpShowIllustrationCharts.groupA+dynamicSurvey.groupB+dashboardFlow.groupB+remoteJobsFilters.groupA+leftPanelUI.groupB+showJobScore.groupC+paidFixedPos.groupB+joblistVsCarousel.groupB+dlpResumeCallout.groupA+animatedCallout.groupB+LTRcityPage.groupA';
#   </script>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.googleapis.com/","@type":"Occupation","mainEntityOfPage":{"@type":"WebPage","lastReviewed":"2020-12-31T00:00:00-08:00"},"estimatedSalary":[{"@type":"MonetaryAmountDistribution","name":"base","currency":"USD","duration":"P1Y","unitText":"YEAR","median":102732,"percentile10":74000,"percentile25":86000,"percentile75":121000,"percentile90":142000}],"occupationLocation":{"@type":"Country","name":"US"}},{"@context":"https://schema.org","@type":"WebPage","dateModified":"2022-02-09T02:00:00-08:00"},{"@context":"https://schema.org","@type":"Person","name":"Dr. Mark Fridline Ph.D.","url":"https://www.zippia.com/data-scientist-jobs/trends/#section-professor-undefined","image":"https://www.uakron.edu/contentAsset/image/1156447/fileAsset/byInode/1/filter/Resize/resize_w/100","jobTitle":"Associate Chair"},{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"How much does a data scientist make?","acceptedAnswer":{"@type":"Answer","text":"<p><b>A data scientist makes around $103,930 a year ($49.97 an hour).</b> The salary range for a data scientist can start anywhere from as low as $52,000 a year to as high as $160,000 a year.</p><p>Variations in pay rate reflect several factors, including the data scientist's industry and the number of years working in the job.</p><p><b>Examples of Industry Pay Rates for Data Scientists:</b></p><ul class=\"large-bullets\"><li><p><b>Computer Systems Design</b> averages $111,490 a year ($53.60 an hour)</p></li><li><p><b>Management of Companies and Enterprises</b> averages $107,980 a year ($51.91 an hour)</p></li><li><p><b>Management, Scientific, and Technical Consulting Services</b> averages $100,800 a year ($48.46 an hour)</p></li><li><p><b>Scientific Research and Development Services</b> averages $109,619 a year ($52.70 an hour)</p></li><li><p><b>Insurance Carriers</b> averages $104,670 a year ($50.33 an hour)</p></li></ul><p><b>Number of years of experience as a data scientist and pay rate:</b></p><ul class=\"large-bullets\"><li><p>Entry-level data scientists (0 to 3 years of experience) start around $95,000 a year.</p></li><li><p>Mid-level data scientists (4 to 7 years of experience) average $130,000 a year.</p></li><li><p>A senior data scientist (8 to 14 years) averages $150,000 a year</p></li><li><p>An experienced data scientist (15 or more years) averages $165,000 a year</p></li></ul>"}},{"@type":"Question","name":"Is data science high-paying?","acceptedAnswer":{"@type":"Answer","text":"<p><b>Yes, data science is high-paying.</b> The median salary for a mid-level data scientist is $130,000 a year. If this data scientist is also in a managerial role, the median salary rises to $195,000 a year.</p><p>Factors that impact the earning potential of a data scientist include the company, the industry, and the job location.</p><p><b>The top-paying companies for data scientists.</b></p><ul class=\"large-bullets\"><li><p>Nvidia: $197,500 a year.</p></li><li><p>Pinterest: $162,931 a year</p></li><li><p>Lyft: $157,900 a year</p></li><li><p>Google: $152,856 a year</p></li><li><p>Apple: $145,974 a year</p></li><li><p>Uber: $144,690 a year</p></li><li><p>Walmart: $137,270 a year</p></li><li><p>Twitter: $135,360 a year</p></li><li><p>Facebook: $134,715 a year</p></li><li><p>PayPal: $132,909 a year</p></li><li><p>Airbnb: $127,852 a year</p></li><li><p>Microsoft: $123,328 a year</p></li></ul><p><b>The industries with the highest median data science salaries are:</b></p><ul class=\"large-bullets\"><li><p>Cloud services, hosting, and CDN</p></li><li><p>Search and social networking</p></li><li><p>Banking and finance</p></li></ul><p><b>Top 5 Paying Industries for Data Scientists.</b></p><ul class=\"large-bullets\"><li><p><b>Computer and Peripheral Equipment Manufacturing</b> averages $144,090 a year ($69.28 an hour)</p></li><li><p><b>Securities, Commodity Contracts, and Other Financial Investments</b> averages $143,490 a year ($68.99 an hour)</p></li><li>< ...
#   </script>
#   <meta content="26" name="next-head-count"/>
#   <link as="style" crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/a02fc78e7910e1a9f127.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-g="" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/a02fc78e7910e1a9f127.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/afa4bab965037dd4ae7a.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/afa4bab965037dd4ae7a.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/37a8067a59ebdf34fee4.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/37a8067a59ebdf34fee4.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/f8b37029d33500b1e862.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/f8b37029d33500b1e862.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/a349de573aee8c57d36b.css" rel="preload"/>
#   <link crossorigin="anonymous" href="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/css/a349de573aee8c57d36b.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script crossorigin="anonymous" defer="" nomodule="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/polyfills-a40ef1678bae11e696dba45124eadd70.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/914.46c03c35e42d1b17f34c.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/117.6a37402713065979aaa9.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/9835.cb4ac2afcae223e7b55a.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/webpack-9a3c00f25dc4ca7bbd6a.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/framework-078c0ea24fcfb6ae03f4.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/main-cec48d0de3e9f03a49ba.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/pages/_app-132a50cc6fee2b7106f7.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/b7fc2e37-cd05483087a3a31cff14.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/e971612a-91ec988672647bbfe8db.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/8278-dbeb3749e84e3f359e4d.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/8579-859d48a430672f6725b4.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/8397-7b8d9e9fc9dbf7a3bc73.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/6127-8d8f9ebb937382725b05.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/7827-42965bf004a4dd074fd4.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/7005-3c2b4aa166021614465f.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/5463-435420b567a911709283.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/551-131adb126ae90843702f.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/5140-43973e42fff4f663b146.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/7505-eea46ef10e728c96eadf.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/3797-28ad42e5a15a2c27f768.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/4763-9f8bac7b5eddd4abb455.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/7156-e35de044f6cdf89609eb.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/1328-061a8770f0796f1b7eaa.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/3065-4b96bc11e706155c89ec.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/703-1d0e240f2ccaa16910f0.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/7423-7423ca894fe907a22cb6.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/chunks/pages/salaryJobPage-8bb3b6d2964a47a84f38.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/EP-zEJrW3fkLbRNLKPpBM/_buildManifest.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://static.zippia.com/ui-router/green/2.4.3.p3/2022-04-28-16-08-17-536/b4b7c4ea43316487e285d61bf3a79e4a4d243a3b/_next/static/EP-zEJrW3fkLbRNLKPpBM/_ssgManifest.js">
#   </script>
#   <style data-href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700|Roboto:300,400,500,700&amp;display=swap">
#    @font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsiH0B4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsjZ0B4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsgH1x4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:700;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsg-1x4gaVQ.woff) format('woff')}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v29/KFOlCnqEu92Fr1MmSU5fBBc-.woff) format('woff')}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v29/KFOmCnqEu92Fr1Mu4mxM.woff) format('woff')}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v29/KFOlCnqEu92Fr1MmEU9fBBc-.woff) format('woff')}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v29/KFOlCnqEu92Fr1MmWUlfBBc-.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSKmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSumu0SC55K5gw.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSOmu0SC55K5gw.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSymu0SC55K5gw.woff2) format('woff2');unicode-range:U+0370-03FF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTS2mu0SC55K5gw.woff2) format('woff2');unicode-range:U+0590-05FF,U+200C-2010,U+20AA,U+25CC,U+FB1D-FB4F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSCmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSGmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v28/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTS-mu0SC55I.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U ...
#   </style>
#  </head>
#  <body>
#   <div id="__next">
#    <header class="header header-new w-100 header_header__jjJql header_withClusterHeader__Wf1BC with-subheader">
#     <nav class="navbar p-0 header_navbar__2U0qW">
#      <div class="container d-flex jusitify-content-between header_container__3fsNC">
#       <div>
#        <div class="d-none d-lg-inline-block float-right">
#         <div class="tab-pane active sitemapCareer-search-fieldset clearfix position-relative sitemap_sitemapCareer-search-fieldset__1NPW0 searchBar_searchBarFieldset__2CeA- searchBar_loggedOut__2TRlF" id="careers" role="tabpanel">
#          <form class="form-inline w-100 searchBar_formInline__fQ3FL">
#           <div class="form-group hi">
#            <div class="rbt clearfix open w-100" style="position:relative" tabindex="-1">
#             <div class="rbt-input-hint-container" style="position:relative">
#              <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input typeahead form-control filterInput z-px-20" data-hj-whitelist="true" id="searchJobTitleSearchBar" name="jobTitle" placeholder="Job Title" role="combobox" type="text" value=""/>
#              <div class="rbt-input-hint" style="left:0;pointer-events:none;position:absolute;top:0;display:inline-block">
#               <input aria-hidden="true" readonly="" style="background-color:transparent;border-color:transparent;box-shadow:none;color:rgba(0, 0, 0, 0.35);box-sizing:content-box;width:1px" tabindex="-1" value=""/>
#               <div style="height:0;left:0;overflow:scroll;position:absolute;top:0;visibility:hidden;white-space:pre">
#               </div>
#              </div>
#             </div>
#             <div aria-atomic="true" aria-live="polite" class="sr-only rbt-sr-status" role="status">
#              0 selections
#             </div>
#            </div>
#           </div>
#           <div class="form-group">
#            <div class="rbt clearfix open w-100" style="position:relative" tabindex="-1">
#             <div class="rbt-input-hint-container" style="position:relative">
#              <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input typeahead form-control filterInput z-px-20" data-hj-whitelist="true" id="searchLocationSearchBar" name="location" placeholder="Location" role="combobox" type="text" value=""/>
#              <div class="rbt-input-hint" style="left:0;pointer-events:none;position:absolute;top:0;display:inline-block">
#               <input aria-hidden="true" readonly="" style="background-color:transparent;border-color:transparent;box-shadow:none;color:rgba(0, 0, 0, 0.35);box-sizing:content-box;width:1px" tabindex="-1" value=""/>
#               <div style="height:0;left:0;overflow:scroll;position:absolute;top:0;visibility:hidden;white-space:pre">
#               </div>
#              </div>
#             </div>
#             <div aria-atomic="true" aria-live="polite" class="sr-only rbt-sr-status" role="status">
#              0 selections
#             </div>
#            </div>
#           </div>
#           <button class="btn btn-orange zpButton_button__GFNgA zpButton_super-primary__BLJac zpButton_big__JyAoM zpButton_full-width__3LJUO" type="submit">
#            <div class="zpButton_content__2B6W0">
#             <div class="zpButton_text__AKuLv">
#              <i class="fa fa-search">
#              </i>
#             </div>
#            </div>
#           </button>
#          </form>
#         </div>
#        </div>
#        <a class="navbar-brand mr-0" href="/">
#         <img alt="Zippia Official Logo" class="header_mobileLogo__3F0hB d-lg-none d-none" height="36" src="https://static.zippia.com/ui-router/images/header/logo_mobile_white.svg" width="36"/>
#         <img alt="Zippia Official Logo" class="header_desktopLogo__3gFK9 d-lg-block" height="36" src="https://static.zippia.com/ui-router/images/header/logo_white.svg" width="160"/>
#        </a>
#       </div>
#       <div class="d-flex align-items-center">
#        <div class="header_options__3TTIj">
#         <ul class="nav navbar-nav header links flex-row mt-0 header_nav__3ALyH">
#          <li class="p-0 m-0 d-none d-lg-block" id="my-jobs-nav">
#           <span class="font-14 link_link__3P0Cs">
#            Jobs
#           </span>
#          </li>
#          <li class="p-0 m-0 d-block d-lg-none">
#           <span class="font-14 link_link__3P0Cs header_mobileSignUp__EikXa">
#            Sign Up
#           </span>
#          </li>
#          <div class="position-relative d-none d-lg-block">
#           <li class="d-none d-md-block m-0 p-0" id="explorer-dropdown">
#            <a class="font-14 link_link__3P0Cs link_exploreLink__WQ3SQ" href="/explore/">
#             Discover
#            </a>
#           </li>
#          </div>
#         </ul>
#        </div>
#        <div class="ml-0">
#         <div class="flex-column flex-lg-row align-items-center d-none d-lg-flex">
#          <button class="custom-btn authMenu_signBtn__2nr5M authMenu_signIn__2Q18N zpButton_button__GFNgA zpButton_primary__2ev7C zpButton_big__JyAoM" type="button">
#           <div class="zpButton_content__2B6W0">
#            <div class="zpButton_text__AKuLv">
#             Log In
#            </div>
#           </div>
#          </button>
#          <button class="custom-btn authMenu_signBtn__2nr5M authMenu_signUp__2NEUI zpButton_button__GFNgA zpButton_primary__2ev7C zpButton_big__JyAoM" type="button">
#           <div class="zpButton_content__2B6W0">
#            <div class="zpButton_text__AKuLv">
#             Sign Up
#            </div>
#           </div>
#          </button>
#         </div>
#        </div>
#        <i class="fa fa-search white-text mr-24 d-block d-lg-none">
#        </i>
#        <div class="hamburger_hamburger__Dnc9S d-flex align-items-center d-block d-lg-none">
#         <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle mt-0 collapsed mr-0 px-0 hamburger_toggle__1_wbP" data-target="#navbar" data-toggle="collapse" type="button">
#          <span class="sr-only">
#          </span>
#          <span class="icon-bar hamburger_iconBar__Dsn3c hamburger_iconBar1__2WAkb">
#          </span>
#          <span class="icon-bar hamburger_iconBar__Dsn3c hamburger_iconBar2__zaCWL">
#          </span>
#          <span class="icon-bar hamburger_iconBar__Dsn3c hamburger_iconBar3__2kxso">
#          </span>
#         </button>
#        </div>
#       </div>
#      </div>
#     </nav>
#     <div class="header_mobileMenu__1zNb-">
#      <div class="header_mobileNavigation__1E5vU">
#       <ul class="m-0 p-0">
#        <li>
#         <span>
#          My Jobs
#          <i aria-hidden="true" class="fa header_faChevronRight__bPkgC header_subFaChevronRight__-nd20">
#          </i>
#         </span>
#        </li>
#        <li>
#         <a class="" href="/explore/">
#          Discover
#          <i aria-hidden="true" class="fa header_faChevronRight__bPkgC header_subFaChevronRight__-nd20">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="" href="/advice/">
#          Job Search Advice
#          <i aria-hidden="true" class="fa header_faChevronRight__bPkgC header_subFaChevronRight__-nd20">
#          </i>
#         </a>
#        </li>
#       </ul>
#       <div class="header_mobileSignBtns__3MQNw">
#        <div class="flex-column flex-lg-row align-items-center d-flex">
#         <button class="custom-btn authMenu_signBtn__2nr5M authMenu_signIn__2Q18N w-100 zpButton_button__GFNgA zpButton_primary__2ev7C zpButton_big__JyAoM zpButton_full-width__3LJUO" type="button">
#          <div class="zpButton_content__2B6W0">
#           <div class="zpButton_text__AKuLv">
#            Log In
#           </div>
#          </div>
#         </button>
#         <button class="custom-btn authMenu_signBtn__2nr5M authMenu_signUp__2NEUI w-100 zpButton_button__GFNgA zpButton_primary__2ev7C zpButton_big__JyAoM zpButton_full-width__3LJUO" type="button">
#          <div class="zpButton_content__2B6W0">
#           <div class="zpButton_text__AKuLv">
#            Sign Up
#           </div>
#          </div>
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <form>
#      <input autocomplete="off" id="username" style="width:0;height:0;visibility:hidden;position:absolute;left:0;top:0" type="text"/>
#      <input autocomplete="off" style="width:0;height:0;visibility:hidden;position:absolute;left:0;top:0" type="password"/>
#     </form>
#     <div class="header_mobileMenu__1zNb-">
#      <div class="tab-pane active sitemapCareer-search-fieldset clearfix position-relative sitemap_sitemapCareer-search-fieldset__1NPW0 searchBar_searchBarFieldset__2CeA- searchBar_loggedOut__2TRlF" id="careers" role="tabpanel">
#       <form class="form-inline w-100 searchBar_formInline__fQ3FL">
#        <div class="form-group hi">
#         <div class="rbt clearfix open w-100" style="position:relative" tabindex="-1">
#          <div class="rbt-input-hint-container" style="position:relative">
#           <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input typeahead form-control filterInput" data-hj-whitelist="true" id="searchJobTitleSearchBar" name="jobTitle" placeholder="Job Title" role="combobox" type="text" value=""/>
#           <div class="rbt-input-hint" style="left:0;pointer-events:none;position:absolute;top:0;display:inline-block">
#            <input aria-hidden="true" readonly="" style="background-color:transparent;border-color:transparent;box-shadow:none;color:rgba(0, 0, 0, 0.35);box-sizing:content-box;width:1px" tabindex="-1" value=""/>
#            <div style="height:0;left:0;overflow:scroll;position:absolute;top:0;visibility:hidden;white-space:pre">
#            </div>
#           </div>
#          </div>
#          <div aria-atomic="true" aria-live="polite" class="sr-only rbt-sr-status" role="status">
#           0 selections
#          </div>
#         </div>
#        </div>
#        <div class="form-group">
#         <div class="rbt clearfix open w-100" style="position:relative" tabindex="-1">
#          <div class="rbt-input-hint-container" style="position:relative">
#           <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input typeahead form-control filterInput" data-hj-whitelist="true" id="searchLocationSearchBar" name="location" placeholder="Location" role="combobox" type="text" value=""/>
#           <div class="rbt-input-hint" style="left:0;pointer-events:none;position:absolute;top:0;display:inline-block">
#            <input aria-hidden="true" readonly="" style="background-color:transparent;border-color:transparent;box-shadow:none;color:rgba(0, 0, 0, 0.35);box-sizing:content-box;width:1px" tabindex="-1" value=""/>
#            <div style="height:0;left:0;overflow:scroll;position:absolute;top:0;visibility:hidden;white-space:pre">
#            </div>
#           </div>
#          </div>
#          <div aria-atomic="true" aria-live="polite" class="sr-only rbt-sr-status" role="status">
#           0 selections
#          </div>
#         </div>
#        </div>
#        <button class="btn btn-orange zpButton_button__GFNgA zpButton_super-primary__BLJac zpButton_big__JyAoM zpButton_full-width__3LJUO" type="submit">
#         <div class="zpButton_content__2B6W0">
#          <div class="zpButton_text__AKuLv">
#           <i class="fa fa-search">
#           </i>
#          </div>
#         </div>
#        </button>
#       </form>
#      </div>
#     </div>
#    </header>
#    <div>
#     <div class="job-title-search container d-flex flex-column-reverse flex-lg-row align-items-start">
#      <h1 class="career-cluster-header-title career-title-only z-my-36">
#       Average Data Scientist Salary
#      </h1>
#      <div class="cluster-header-search-bar-container z-mt-12 z-mb-20 z-mb-lg-0 z-ml-lg-20 z-mt-lg-40">
#       <div class="rbt clearfix open" style="position:relative" tabindex="-1">
#        <div class="rbt-input-hint-container" style="position:relative">
#         <input aria-autocomplete="both" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="rbt-input-main form-control rbt-input typeahead form-control filterInput" data-hj-whitelist="true" name="jobTitle" placeholder="Search For A Job Title" role="combobox" type="text" value=""/>
#         <div class="rbt-input-hint" style="left:0;pointer-events:none;position:absolute;top:0;display:inline-block">
#          <input aria-hidden="true" readonly="" style="background-color:transparent;border-color:transparent;box-shadow:none;color:rgba(0, 0, 0, 0.35);box-sizing:content-box;width:1px" tabindex="-1" value=""/>
#          <div style="height:0;left:0;overflow:scroll;position:absolute;top:0;visibility:hidden;white-space:pre">
#          </div>
#         </div>
#        </div>
#        <div aria-atomic="true" aria-live="polite" class="sr-only rbt-sr-status" role="status">
#         0 selections
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sub-header-container">
#      <div class="cluster-subheader navbar-tabs" id="navigation">
#       <div class="tabs-container container">
#        <div class="subheaders-links-container">
#         <a class="tab-list-item" href="/data-scientist-jobs/">
#          Overview
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/jobs/">
#          Jobs
#         </a>
#         <p class="tab-list-item tab-list-active">
#          Salary
#         </p>
#         <a class="tab-list-item" href="/data-scientist-jobs/resume/">
#          Resume
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/skills/">
#          Skills
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/what-does-a-data-scientist-do/">
#          What They Do
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/education/">
#          Education
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/certifications/">
#          Certifications
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/demographics/">
#          Demographics
#         </a>
#         <a class="tab-list-item" href="/data-scientist-jobs/best-states/">
#          Best States
#         </a>
#         <div class="d-none d-xl-block">
#          <div class="MoreItemsDropdown_more-items-dropdown-container__3wVI8" id="more-items-dropdown">
#           <span class="MoreItemsDropdown_dropdown-toggler__1BmVc">
#            More
#            <i aria-hidden="true" class="submenuArrowIcon">
#            </i>
#           </span>
#           <ul class="MoreItemsDropdown_more-items-dropdown-list__3b9zx">
#            <li class="MoreItemsDropdown_more-items-dropdown-list-item__LqZj3">
#             <a href="/data-scientist-jobs/remote-jobs/">
#              Remote Jobs
#             </a>
#            </li>
#            <li class="MoreItemsDropdown_more-items-dropdown-list-item__LqZj3">
#             <a href="/data-scientist-jobs/trends/">
#              Trends
#             </a>
#            </li>
#            <li class="MoreItemsDropdown_more-items-dropdown-list-item__LqZj3">
#             <a href="/data-scientist-jobs/cover-letter/">
#              Cover Letter
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="submenuArrow submenuArrowRight">
#          <i aria-hidden="true" class="submenuArrowIcon">
#          </i>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container" id="in-page-nav">
#      <div class="inPageNavigation_inPageNavigationContainer__1Kzyr w-100 mt-5 d-xl-flex justify-content-between">
#       <div>
#        <div class="inPageNavigation_onThisPageContainer__3kpPl d-flex flex-row flex-xl-column">
#         <p class="mr-2 m-xl-0 openSansBlackBold">
#          On This Page
#         </p>
#         <p class="inPageNavigation_skipToSectionText__11Y0g m-0">
#          Skip to section
#         </p>
#        </div>
#       </div>
#       <div class="inPageNavigation_inPageNavigationSectionContainer__nwxQD d-flex align-items-center">
#        <div class="d-flex align-items-center">
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#average-salary-chart">
#          Average Salary
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#salary-by-state">
#          By State
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#salary-history-line-chart">
#          Over Time
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#by-industry">
#          By Industry
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#by-field">
#          By Field
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#by-company">
#          By Company
#         </a>
#         <a class="inPageNavigation_inPageNavigationSection__3rB4W open-sans-medium-black mr-4" href="/data-scientist-jobs/salary/#salary-demographics">
#          By Demographics
#         </a>
#        </div>
#        <div class="d-inline d-xl-none submenuArrow submenuArrowRight">
#         <i aria-hidden="true" class="submenuArrowIcon">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="salaryJobPage_salary-page-container__1pDCK container">
#      <div class="d-flex justify-content-between">
#       <div class="d-block w-730">
#        <section class="graphic-designer-salaries-section" id="average-salary-chart">
#         <div class="d-flex flex-column flex-xl-row justify-content-between header-section-container">
#          <div>
#           <div class="salary-designer-body">
#            <div class="salary-graphic-area-left w-100">
#             <div class="mt-3 salary-job-filters-container d-md-flex justify-content-md-between align-items-md-center">
#              <div class="zpFilter_zp-filter-group__2YOgI zp-filter-group">
#               <div class="zpFilter_filter-carousel-container__1j0UM filter-carousel-container">
#                <div class="zpFilter_filter-carousel__14BkG d-none d-lg-flex">
#                 <div class="zpFilter_zp-filter-container__DGGB8 zp-filter-container">
#                  <button class="zpBtn zpFilter_zp-filter-button__DAXCR zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_small__3Xmxh zpButton_with-right-icon__2BSFu zpButton_btn-dropdown__2NWEq" type="button">
#                   <div class="zpButton_content__2B6W0 zpButton_dropdown-content__1OI6r">
#                    <div class="zpButton_text__AKuLv">
#                     Location
#                    </div>
#                   </div>
#                  </button>
#                 </div>
#                 <div class="zpFilter_zp-filter-container__DGGB8 zp-filter-container">
#                  <button class="zpBtn zpFilter_zp-filter-button__DAXCR zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_small__3Xmxh zpButton_with-right-icon__2BSFu zpButton_btn-dropdown__2NWEq" type="button">
#                   <div class="zpButton_content__2B6W0 zpButton_dropdown-content__1OI6r">
#                    <div class="zpButton_text__AKuLv">
#                     Industry
#                    </div>
#                   </div>
#                  </button>
#                 </div>
#                 <div class="zpFilter_zp-filter-container__DGGB8 zp-filter-container">
#                  <button class="zpBtn zpFilter_zp-filter-button__DAXCR zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_small__3Xmxh zpButton_with-right-icon__2BSFu zpButton_btn-dropdown__2NWEq" type="button">
#                   <div class="zpButton_content__2B6W0 zpButton_dropdown-content__1OI6r">
#                    <div class="zpButton_text__AKuLv">
#                     Education
#                    </div>
#                   </div>
#                  </button>
#                 </div>
#                </div>
#                <div class="d-flex d-lg-none">
#                 <div class="zpFilter_zp-filter-container__DGGB8 zp-filter-container">
#                  <button class="zpBtn zpFilter_zp-filter-button__DAXCR zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_small__3Xmxh zpButton_with-right-icon__2BSFu zpButton_btn-dropdown__2NWEq" type="button">
#                   <div class="zpButton_content__2B6W0 zpButton_dropdown-content__1OI6r">
#                    <div class="zpButton_text__AKuLv">
#                     Location
#                    </div>
#                   </div>
#                  </button>
#                 </div>
#                 <button class="zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_small__3Xmxh zpButton_with-right-icon__2BSFu zpButton_btn-dropdown__2NWEq" type="button">
#                  <div class="zpButton_content__2B6W0 zpButton_dropdown-content__1OI6r">
#                   <div class="zpButton_text__AKuLv">
#                    Filters
#                   </div>
#                  </div>
#                 </button>
#                </div>
#               </div>
#              </div>
#              <div>
#               <div class="last-updated-date" itemprop="dateModified">
#                Updated February 9, 2022
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="salary-graphic-area-right">
#             <div class="median-salary-container">
#              <div>
#               <div class="HeaderSection_salaryGraphJobTitleHeader__3kxDb openSansBlackBold mb-2">
#                Average Data Scientist Salary
#               </div>
#               <div class="average-salary-number">
#                $102,000
#                <span>
#                 yearly
#                </span>
#                <div class="salaryChartTooltip_salaryChartTooltip__1qkxc">
#                 <div class="tip-container">
#                  <span class="tip-icon">
#                   <svg fill="none" height="16" stroke="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                    <circle cx="8" cy="8" fill="#7D878F" r="8">
#                    </circle>
#                    <path d="M9 3H7V5H9V3Z" fill="#FFFFFF">
#                    </path>
#                    <path d="M9 7H7V13H9V7Z" fill="#FFFFFF">
#                    </path>
#                   </svg>
#                  </span>
#                  <div class="tip-block">
#                   To create our salary estimates, Zippia starts with data published in publicly available sources such as the U.S. Bureau of Labor Statistics (BLS), Foreign Labor Certification Data Center (FLC)
#                   <!-- -->
#                   <a href="/salary-methodology/" target="_blank">
#                    Show More
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="hourly-rate-number">
#                $49.39 hourly
#               </div>
#               <hr/>
#               <div class="entry-level-salary">
#                <div>
#                 Entry level Salary
#                </div>
#                <span>
#                 $74,000
#                 <!-- -->
#                 yearly
#                </span>
#               </div>
#              </div>
#              <div class="salary-chart-wrapper">
#               <div class="salary-chart">
#                <div class="first svg">
#                 <div class="bottom" style="height:40px;background-color:rgba(186, 196, 218, 0.3);border-bottom:3px solid #BAC4DA;transition:height 500ms ease-in-out">
#                 </div>
#                 <div class="number">
#                  $74,000
#                 </div>
#                 <div class="number-description">
#                  10 %
#                 </div>
#                </div>
#                <div class="second svg">
#                 <div class="bottom" style="height:58px;background-color:#B8DFDD;border-bottom:3px solid #26A69A;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="third svg">
#                 <div class="bottom" style="height:68px;background-color:#B8DFDD;border-bottom:3px solid #26A69A;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="fourth svg">
#                 <div class="bottom" style="height:70px;background-color:#26A69A;border-bottom:3px solid #26A69A;transition:height 500ms ease-in-out">
#                 </div>
#                 <div class="median-container">
#                  <div class="number median">
#                   $102,000
#                  </div>
#                  <div class="number-description number-description-median">
#                   Median
#                  </div>
#                 </div>
#                </div>
#                <div class="fifth svg">
#                 <div class="bottom" style="height:63px;background-color:#B8DFDD;border-bottom:3px solid #26A69A;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="sixth svg">
#                 <div class="bottom" style="height:53px;background-color:#B8DFDD;border-bottom:3px solid #26A69A;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="seventh svg">
#                 <div class="bottom" style="height:41px;background-color:rgba(186, 196, 218, 0.3);border-bottom:3px solid #BAC4DA;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="eighth svg">
#                 <div class="bottom" style="height:30px;background-color:rgba(186, 196, 218, 0.3);border-bottom:3px solid #BAC4DA;transition:height 500ms ease-in-out">
#                 </div>
#                </div>
#                <div class="ninth svg">
#                 <div class="bottom" style="height:21px;background-color:rgba(186, 196, 218, 0.3);border-bottom:3px solid #BAC4DA;transition:height 500ms ease-in-out">
#                 </div>
#                 <div class="number">
#                  $142,000
#                 </div>
#                 <div class="number-description number-description-90">
#                  90 %
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="HeaderSection_calloutWrap__2R-FF openSansBlackBold mt-24">
#            <div class="HeaderSection_calloutImageContainer__3VXip">
#             <img alt="Calculator" height="39" src="https://static.zippia.com/ui-router/images/callouts/salary/calculator.svg" width="38"/>
#            </div>
#            <div class="HeaderSection_calloutText__2iRiK">
#             Are you paid fairly?
#             <span class="list-link">
#              Get Your Salary Estimate
#             </span>
#            </div>
#           </div>
#           <div class="HeaderSection_salaryPercentileTable__1ABrN">
#            <div class="table_scrollable__vd8cX">
#             <h3 class="zp-title-h3 text-capitalize mb-4">
#              What is a Data Scientist's Salary?
#             </h3>
#             <table class="table_table__1SUby custom-table">
#              <thead>
# ...
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/senior-data-scientist-jobs/" title="Senior Data Scientist">
#            How To Become a Senior Data Scientist
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/statistician-jobs/" title="Statistician">
#            How To Become a Statistician
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-12 col-lg-3 mt-4">
#         <h3 class="footer-link-list-title">
#          Data Scientist Related Jobs
#         </h3>
#         <ul class="footer-link-list">
#          <li class="footer-link-list-item">
#           <a href="/bioinformatics-computer-scientist-jobs/jobs/" title="Bioinformatics Computer Scientist">
#            Bioinformatics Computer Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/computer-scientist-jobs/jobs/" title="Computer Scientist">
#            Computer Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/control-system-computer-scientist-jobs/jobs/" title="Control System Computer Scientist">
#            Control System Computer Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-analyst-jobs/jobs/" title="Data Analyst">
#            Data Analyst Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-analyst-internship-jobs/jobs/" title="Data Analyst Internship">
#            Data Analyst Internship Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-consultant-jobs/jobs/" title="Data Consultant">
#            Data Consultant Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-engineer-jobs/jobs/" title="Data Engineer">
#            Data Engineer Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-science-internship-jobs/jobs/" title="Data Science Internship">
#            Data Science Internship Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/developer-analyst-jobs/jobs/" title="Developer Analyst">
#            Developer Analyst Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/geospatial-scientist-jobs/jobs/" title="Geospatial Scientist">
#            Geospatial Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/information-scientist-jobs/jobs/" title="Information Scientist">
#            Information Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/operations-research-analyst-jobs/jobs/" title="Operations Research Analyst">
#            Operations Research Analyst Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/research-and-development-internship-jobs/jobs/" title="Research And Development Internship">
#            Research And Development Internship Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/scientist-jobs/jobs/" title="Scientist">
#            Scientist Jobs
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/senior-computer-scientist-jobs/jobs/" title="Senior Computer Scientist">
#            Senior Computer Scientist Jobs
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-12 col-lg-3 mt-4">
#         <h3 class="footer-link-list-title">
#          What Similar Roles Do
#         </h3>
#         <ul class="footer-link-list">
#          <li class="footer-link-list-item">
#           <a href="/computer-scientist-jobs/what-does-a-computer-scientist-do/" title="Computer Scientist">
#            What a Computer Scientist Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-analyst-jobs/what-does-a-data-analyst-do/" title="Data Analyst">
#            What a Data Analyst Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-analyst-internship-jobs/what-does-a-data-analyst-internship-do/" title="Data Analyst Internship">
#            What a Data Analyst Internship Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-consultant-jobs/what-does-a-data-consultant-do/" title="Data Consultant">
#            What a Data Consultant Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-engineer-jobs/what-does-a-data-engineer-do/" title="Data Engineer">
#            What a Data Engineer Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/data-science-internship-jobs/what-does-a-data-science-internship-do/" title="Data Science Internship">
#            What a Data Science Internship Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/developer-analyst-jobs/what-does-a-developer-analyst-do/" title="Developer Analyst">
#            What a Developer Analyst Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/information-scientist-jobs/what-does-an-information-scientist-do/" title="Information Scientist">
#            What an Information Scientist Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/operations-research-analyst-jobs/what-does-an-operations-research-analyst-do/" title="Operations Research Analyst">
#            What an Operations Research Analyst Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/research-and-development-internship-jobs/what-does-a-research-and-development-internship-do/" title="Research And Development Internship">
#            What a Research And Development Internship Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/scientist-jobs/what-does-a-scientist-do/" title="Scientist">
#            What a Scientist Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/senior-computer-scientist-jobs/what-does-a-senior-computer-scientist-do/" title="Senior Computer Scientist">
#            What a Senior Computer Scientist Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/senior-data-scientist-jobs/what-does-a-senior-data-scientist-do/" title="Senior Data Scientist">
#            What a Senior Data Scientist Does
#           </a>
#          </li>
#          <li class="footer-link-list-item">
#           <a href="/statistician-jobs/what-does-a-statistician-do/" title="Statistician">
#            What a Statistician Does
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </section>
#      <div class="container px-0">
#       <div class="container bottom-cluster-navigation px-0 d-flex justify-content-between align-items-center">
#        <button class="prev d-sm-flex d-none zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_big__JyAoM zpButton_with-icon__2Qz1Z zpButton_with-left-icon__23zUi" type="button">
#         <div class="zpButton_content__2B6W0">
#          <div class="zpButton_content__2B6W0 zpButton_icon__3tUqd zpButton_icon-left__2gftR">
#           <i aria-hidden="true" class="submenuArrowIcon">
#           </i>
#          </div>
#          <div class="zpButton_text__AKuLv">
#           <span class="button-direction">
#            Previous:
#           </span>
#           <span class="page-name">
#            Overview
#           </span>
#          </div>
#         </div>
#        </button>
#        <button class="next zpButton_button__GFNgA zpButton_secondary__1icC1 zpButton_big__JyAoM zpButton_with-icon__2Qz1Z zpButton_with-right-icon__2BSFu" type="button">
#         <div class="zpButton_content__2B6W0">
#          <div class="zpButton_text__AKuLv">
#           <span class="button-direction">
#            Next:
#           </span>
#           <span class="page-name">
#            Overview
#           </span>
#          </div>
#          <div class="zpButton_content__2B6W0 zpButton_icon__3tUqd zpButton_icon-right__NMSt1">
#           <i aria-hidden="true" class="submenuArrowIcon">
#           </i>
#          </div>
#         </div>
#        </button>
#       </div>
#      </div>
#      <section class="container breadcrumbs-salary-section">
#       <div class="BreadCrumbs_locationBreadcrumbs__3PuXl locationBreadcrumbs p-0 m-0 salaryBreadCrumbsContainer row">
#        <ul class="breadcrumb custom-breadcrumb col-12 col-lg-9 order-last order-lg-first">
#         <li>
#          <a href="https://www.zippia.com/careers/">
#           Zippia Careers
#          </a>
#         </li>
#         <li>
#          <a href="https://www.zippia.com/computer-and-mathematical-industry/">
#           Computer and Mathematical Industry
#          </a>
#         </li>
#         <li>
#          <a href="https://www.zippia.com/data-scientist-jobs/">
#           Data Scientist
#          </a>
#         </li>
#         <li>
#          Data Scientist Salary
#         </li>
#        </ul>
#        <div class="col-12 col-lg-3 order-first order-lg-last pl-0 pr-0 mb-3 mb-lg-0 average-salary-text last-updated-date" itemprop="dateModified">
#         Updated February 9, 2022
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#    <footer class="footer">
#     <div class="container">
#      <div class="row mb-5">
#       <div class="col-12">
#       </div>
#      </div>
#     </div>
#     <div class="container">
#      <div class="row footer-nav">
#       <div class="col-md-3 col-12 footer-logo mb-3 mb-md-0">
#        <a href="/">
#         <img alt="Zippia" height="36" src="https://static.zippia.com/ui-router/images/footer/logo_footer.svg" width="153"/>
#        </a>
#       </div>
#       <div class="col-md-3 col-6">
#        <div class="semi-bold-font text-uppercase h6 mt-0">
#         Zippia
#        </div>
#        <ul class="p-0 m-0">
#         <li>
#          <a href="/about-us/">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="/employer/">
#           Employer Services
#          </a>
#         </li>
#         <li>
#          <a href="/terms-of-use/">
#           Terms of Use
#          </a>
#         </li>
#         <li>
#          <a href="/privacy-policy/">
#           Privacy Policy
#          </a>
#         </li>
#         <li>
#          <a href="/contact-us/">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3 col-6">
#        <div class="semi-bold-font text-uppercase h6 mt-0 footer-career-jobs">
#         Careers &amp; Jobs
#        </div>
#        <ul class="p-0 m-0">
#         <li>
#          <a href="/advice/">
#           Careers Advice
#          </a>
#         </li>
#         <li>
#          <a href="/careers/">
#           Careers by Categories
#          </a>
#         </li>
#         <li>
#          <a href="/jobs/">
#           Jobs by Location
#          </a>
#         </li>
#         <li>
#          <a href="/colleges-and-majors/">
#           College Grad Careers
#          </a>
#         </li>
#         <li>
#          <a href="/resume-builder/?src=footer">
#           Resume Builder
#          </a>
#         </li>
#         <li>
#          <a href="/answers/">
#           Job Search Q&amp;A
#          </a>
#         </li>
#         <li>
#          <a href="/up-and-coming-jobs/">
#           Up and Coming Jobs
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3 col-12 mt-4 mt-md-0">
#        <p class="footer-text">
#         Email:
#         <span class="email-text">
#          support@zippia.com
#         </span>
#        </p>
#        <p class="footer-text">
#         Copyright © 2022 Zippia, Inc.
#        </p>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script crossorigin="anonymous" id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"data":{"metadata":{"PUBLISHED_TIME":"2020-05-18T00:00:00-08:00","MODIFIED_TIME":"2022-02-09T02:00:00-08:00","UPDATED_TIME":"2022-02-09T02:00:00-08:00","lastReviewed":"2020-12-31T00:00:00-08:00","pageCategory":"Career Salary Page","TITLE":"Data Scientist Salary (April 2022) - Zippia | Average Data Scientist Salaries Hourly And Annual","META_DESCRIPTION":"The average salary for \u003cjobTitleArticle\u003e Data Scientist is $102,000 per year, or $49.39 per hour in United States. Find out the average by state, years of experience, field. Data Scientist gender pay gap, race wage gap and income by education level.","OG_TITLE":"Data Scientist Salary (April 2022) - Zippia | Average Data Scientist Salaries Hourly And Annual","OG_META_DESCRIPTION":"The average salary for \u003cjobTitleArticle\u003e Data Scientist is $102,000 per year, or $49.39 per hour in United States. Find out the average by state, years of experience, field. Data Scientist gender pay gap, race wage gap and income by education level.","host":"https://www.zippia.com","url":"/data-scientist-jobs/salary/","relCanonical":{"rel":"canonical","href":"https://www.zippia.com/data-scientist-jobs/salary/"},"structuredData":[{"@context":"http://schema.googleapis.com/","@type":"Occupation","mainEntityOfPage":{"@type":"WebPage","lastReviewed":"2020-12-31T00:00:00-08:00"},"estimatedSalary":[{"@type":"MonetaryAmountDistribution","name":"base","currency":"USD","duration":"P1Y","unitText":"YEAR","median":102732,"percentile10":74000,"percentile25":86000,"percentile75":121000,"percentile90":142000}],"occupationLocation":{"@type":"Country","name":"US"}},{"@context":"https://schema.org","@type":"WebPage","dateModified":"2022-02-09T02:00:00-08:00"},{"@context":"https://schema.org","@type":"Person","name":"Dr. Mark Fridline Ph.D.","url":"https://www.zippia.com/data-scientist-jobs/trends/#section-professor-undefined","image":"https://www.uakron.edu/contentAsset/image/1156447/fileAsset/byInode/1/filter/Resize/resize_w/100","jobTitle":"Associate Chair"},{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"How much does a data scientist make?","acceptedAnswer":{"@type":"Answer","text":"\u003cp\u003e\u003cb\u003eA data scientist makes around $103,930 a year ($49.97 an hour).\u003c/b\u003e The salary range for a data scientist can start anywhere from as low as $52,000 a year to as high as $160,000 a year.\u003c/p\u003e\u003cp\u003eVariations in pay rate reflect several factors, including the data scientist's industry and the number of years working in the job.\u003c/p\u003e\u003cp\u003e\u003cb\u003eExamples of Industry Pay Rates for Data Scientists:\u003c/b\u003e\u003c/p\u003e\u003cul class=\"large-bullets\"\u003e\u003cli\u003e\u003cp\u003e\u003cb\u003eComputer Systems Design\u003c/b\u003e averages $111,490 a year ($53.60 an hour)\u003c/p\u003e\u003c/li\u003e\u003cli\u003e\u003cp\u003e\u003cb\u003eManagement of Companies and Enterprises\u003c/b\u003e averages $107,980 a year ($51.91 an hour)\u003c/p\u003e\u003c/li\u003e\u003cli\u003e\u003cp\u003e\u003cb\u003eManagement, Scientific, and Technical Consulting Services\u003c/b\u003e averages $100,800 a year ($48.46 an hour)\u003c/p\u003e\u003c/li\u003e\u003cli\u003e\u003cp\u003e\u003cb\u003eScientific Research and Development Services\u003c/b\u003e averages $109,619 a year ($52.70 an hour)\u003c/p\u003e\u003c/li\u003e\u003cli\u003e\u003cp\u003e\u003cb\u003eInsurance Carriers\u003c/b\u003e averages $104,670 a year ($50.33 an hour)\u003c/p\u003e\u003c/li\u003e\u003c/ul\u003e\u003cp\u003e\u003cb\u003eNumber of years of experience as a data scientist and pay rate:\u003c/b\u003e\u003c/p\u003e\u003cul class=\"large-bullets\"\u003e\u003cli\u003e\u003cp\u003eEntry-level data scientists (0 to 3 years of experience) start around $95,000 a year.\u003c/p\u003e\u003c/li\u003e\u003cli\u003e\u003cp\u003eMid-level data scientists (4 to 7 years of experience) average $130,000 a year.\u003c/p\u003e\u00 ...
#   </script>
#  </body>
# </html>

# %%
all_tables = soup.find_all('table')
print("There are {} tables in this file.".format(len(all_tables)))
# Out:
# There are 12 tables in this file.

# %%
all_tables[2]
# Out:
# <table class="table_table__1SUby custom-table"><thead><tr class="table_headRow__3CMnb table-head-row"><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">City</th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Avg. Salary</th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Hourly Rate</th></tr></thead><tbody></tbody></table>

# %%
city_table = all_tables[2]

# %%
print(type(city_table))
# Out:
# <class 'bs4.element.Tag'>

# %%
print(city_table.prettify())
# Out:
# <table class="table_table__1SUby custom-table">
#  <thead>
#   <tr class="table_headRow__3CMnb table-head-row">
#    <th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">
#     City
#    </th>
#    <th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">
#     Avg. Salary
#    </th>
#    <th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">
#     Hourly Rate
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#  </tbody>
# </table>

# %%
string = '''
<table class="table_table__1SUby custom-table"><thead><tr class="table_headRow__3CMnb table-head-row"><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font table_selected__1rekk">City<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1 selected" alt="asc" width="8" height="5"></a></th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Avg. Salary<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Hourly Rate<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th></tr></thead><tbody><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Arlington, VA</td><td class="table_data__1f5rh table-data z-pl-20">$90,649</td><td class="table_data__1f5rh table-data z-pl-20">$43.58</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Austin, TX</td><td class="table_data__1f5rh table-data z-pl-20">$88,720</td><td class="table_data__1f5rh table-data z-pl-20">$42.65</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Bentonville, AR</td><td class="table_data__1f5rh table-data z-pl-20">$82,474</td><td class="table_data__1f5rh table-data z-pl-20">$39.65</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Boston, MA</td><td class="table_data__1f5rh table-data z-pl-20">$94,202</td><td class="table_data__1f5rh table-data z-pl-20">$45.29</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Chicago, IL</td><td class="table_data__1f5rh table-data z-pl-20">$86,137</td><td class="table_data__1f5rh table-data z-pl-20">$41.41</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Columbus, GA</td><td class="table_data__1f5rh table-data z-pl-20">$82,140</td><td class="table_data__1f5rh table-data z-pl-20">$39.49</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Columbus, OH</td><td class="table_data__1f5rh table-data z-pl-20">$86,664</td><td class="table_data__1f5rh table-data z-pl-20">$41.67</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Denver, CO</td><td class="table_data__1f5rh table-data z-pl-20">$81,990</td><td class="table_data__1f5rh table-data z-pl-20">$39.42</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Detroit, MI</td><td class="table_data__1f5rh table-data z-pl-20">$86,286</td><td class="table_data__1f5rh table-data z-pl-20">$41.48</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Jersey City, NJ</td><td class="table_data__1f5rh table-data z-pl-20">$94,662</td><td class="table_data__1f5rh table-data z-pl-20">$45.51</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Madison, WI</td><td class="table_data__1f5rh table-data z-pl-20">$81,874</td><td class="table_data__1f5rh table-data z-pl-20">$39.36</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Minneapolis, MN</td><td class="table_data__1f5rh table-data z-pl-20">$86,134</td><td class="table_data__1f5rh table-data z-pl-20">$41.41</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">New York, NY</td><td class="table_data__1f5rh table-data z-pl-20">$102,427</td><td class="table_data__1f5rh table-data z-pl-20">$49.24</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Philadelphia, PA</td><td class="table_data__1f5rh table-data z-pl-20">$90,231</td><td class="table_data__1f5rh table-data z-pl-20">$43.38</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Phoenix, AZ</td><td class="table_data__1f5rh table-data z-pl-20">$88,469</td><td class="table_data__1f5rh table-data z-pl-20">$42.53</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Raleigh, NC</td><td class="table_data__1f5rh table-data z-pl-20">$83,965</td><td class="table_data__1f5rh table-data z-pl-20">$40.37</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Saint Louis, MO</td><td class="table_data__1f5rh table-data z-pl-20">$81,195</td><td class="table_data__1f5rh table-data z-pl-20">$39.04</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">San Francisco, CA</td><td class="table_data__1f5rh table-data z-pl-20">$138,170</td><td class="table_data__1f5rh table-data z-pl-20">$66.43</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Seattle, WA</td><td class="table_data__1f5rh table-data z-pl-20">$122,139</td><td class="table_data__1f5rh table-data z-pl-20">$58.72</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Washington, DC</td><td class="table_data__1f5rh table-data z-pl-20">$92,707</td><td class="table_data__1f5rh table-data z-pl-20">$44.57</td></tr></tbody></table>'''
city_list = pd.read_html(string)

# %%
city_df = pd.concat(city_list)
city_df
# Out:
#                  City Avg. Salary Hourly Rate
# 0       Arlington, VA     $90,649      $43.58
# 1          Austin, TX     $88,720      $42.65
# 2     Bentonville, AR     $82,474      $39.65
# 3          Boston, MA     $94,202      $45.29
# 4         Chicago, IL     $86,137      $41.41
# 5        Columbus, GA     $82,140      $39.49
# 6        Columbus, OH     $86,664      $41.67
# 7          Denver, CO     $81,990      $39.42
# 8         Detroit, MI     $86,286      $41.48
# 9     Jersey City, NJ     $94,662      $45.51
# 10        Madison, WI     $81,874      $39.36
# 11    Minneapolis, MN     $86,134      $41.41
# 12       New York, NY    $102,427      $49.24
# 13   Philadelphia, PA     $90,231      $43.38
# 14        Phoenix, AZ     $88,469      $42.53
# 15        Raleigh, NC     $83,965      $40.37
# 16    Saint Louis, MO     $81,195      $39.04
# 17  San Francisco, CA    $138,170      $66.43
# 18        Seattle, WA    $122,139      $58.72
# 19     Washington, DC     $92,707      $44.57

# %%
string2 = '''
<table class="table_table__1SUby custom-table"><thead><tr class="table_headRow__3CMnb table-head-row"><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">State<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Avg. Salary<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Hourly Rate<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th><th class="table_head__2GBnl z-pr-0 z-pr-md-4 z-pl-20 position-relative custom-table-head semi-bold-font">Job Count<a class="table_sort__3OGio d-inline-block text-center z-ml-4 sortyby"><img src="https://static.zippia.com/ui-router/images/top_sort_unselected.png" class="position-relative z-m-1" alt="asc" width="8" height="5"><img src="https://static.zippia.com/ui-router/images/bottom_sort_unselected.png" class="position-relative z-m-1" alt="desc" width="8" height="5"></a></th></tr></thead><tbody><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Alabama</td><td class="table_data__1f5rh table-data z-pl-20">$77,743</td><td class="table_data__1f5rh table-data z-pl-20">$37.38</td><td class="table_data__1f5rh table-data z-pl-20">390</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Alaska</td><td class="table_data__1f5rh table-data z-pl-20">$84,755</td><td class="table_data__1f5rh table-data z-pl-20">$40.75</td><td class="table_data__1f5rh table-data z-pl-20">148</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Arizona</td><td class="table_data__1f5rh table-data z-pl-20">$88,333</td><td class="table_data__1f5rh table-data z-pl-20">$42.47</td><td class="table_data__1f5rh table-data z-pl-20">831</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Arkansas</td><td class="table_data__1f5rh table-data z-pl-20">$82,909</td><td class="table_data__1f5rh table-data z-pl-20">$39.86</td><td class="table_data__1f5rh table-data z-pl-20">266</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">California</td><td class="table_data__1f5rh table-data z-pl-20">$126,682</td><td class="table_data__1f5rh table-data z-pl-20">$60.90</td><td class="table_data__1f5rh table-data z-pl-20">3,874</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Colorado</td><td class="table_data__1f5rh table-data z-pl-20">$82,112</td><td class="table_data__1f5rh table-data z-pl-20">$39.48</td><td class="table_data__1f5rh table-data z-pl-20">877</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Connecticut</td><td class="table_data__1f5rh table-data z-pl-20">$92,237</td><td class="table_data__1f5rh table-data z-pl-20">$44.34</td><td class="table_data__1f5rh table-data z-pl-20">678</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Delaware</td><td class="table_data__1f5rh table-data z-pl-20">$95,563</td><td class="table_data__1f5rh table-data z-pl-20">$45.94</td><td class="table_data__1f5rh table-data z-pl-20">241</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">District of Columbia</td><td class="table_data__1f5rh table-data z-pl-20">$92,648</td><td class="table_data__1f5rh table-data z-pl-20">$44.54</td><td class="table_data__1f5rh table-data z-pl-20">504</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Florida</td><td class="table_data__1f5rh table-data z-pl-20">$76,936</td><td class="table_data__1f5rh table-data z-pl-20">$36.99</td><td class="table_data__1f5rh table-data z-pl-20">1,801</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Georgia</td><td class="table_data__1f5rh table-data z-pl-20">$81,997</td><td class="table_data__1f5rh table-data z-pl-20">$39.42</td><td class="table_data__1f5rh table-data z-pl-20">1,275</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Hawaii</td><td class="table_data__1f5rh table-data z-pl-20">$85,453</td><td class="table_data__1f5rh table-data z-pl-20">$41.08</td><td class="table_data__1f5rh table-data z-pl-20">160</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Idaho</td><td class="table_data__1f5rh table-data z-pl-20">$88,982</td><td class="table_data__1f5rh table-data z-pl-20">$42.78</td><td class="table_data__1f5rh table-data z-pl-20">249</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Illinois</td><td class="table_data__1f5rh table-data z-pl-20">$85,726</td><td class="table_data__1f5rh table-data z-pl-20">$41.21</td><td class="table_data__1f5rh table-data z-pl-20">2,023</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Indiana</td><td class="table_data__1f5rh table-data z-pl-20">$79,391</td><td class="table_data__1f5rh table-data z-pl-20">$38.17</td><td class="table_data__1f5rh table-data z-pl-20">712</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Iowa</td><td class="table_data__1f5rh table-data z-pl-20">$78,285</td><td class="table_data__1f5rh table-data z-pl-20">$37.64</td><td class="table_data__1f5rh table-data z-pl-20">427</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Kansas</td><td class="table_data__1f5rh table-data z-pl-20">$78,037</td><td class="table_data__1f5rh table-data z-pl-20">$37.52</td><td class="table_data__1f5rh table-data z-pl-20">388</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Kentucky</td><td class="table_data__1f5rh table-data z-pl-20">$78,352</td><td class="table_data__1f5rh table-data z-pl-20">$37.67</td><td class="table_data__1f5rh table-data z-pl-20">396</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Louisiana</td><td class="table_data__1f5rh table-data z-pl-20">$80,084</td><td class="table_data__1f5rh table-data z-pl-20">$38.50</td><td class="table_data__1f5rh table-data z-pl-20">315</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Maine</td><td class="table_data__1f5rh table-data z-pl-20">$78,384</td><td class="table_data__1f5rh table-data z-pl-20">$37.68</td><td class="table_data__1f5rh table-data z-pl-20">196</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Maryland</td><td class="table_data__1f5rh table-data z-pl-20">$90,523</td><td class="table_data__1f5rh table-data z-pl-20">$43.52</td><td class="table_data__1f5rh table-data z-pl-20">1,516</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Massachusetts</td><td class="table_data__1f5rh table-data z-pl-20">$94,404</td><td class="table_data__1f5rh table-data z-pl-20">$45.39</td><td class="table_data__1f5rh table-data z-pl-20">1,684</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Michigan</td><td class="table_data__1f5rh table-data z-pl-20">$86,008</td><td class="table_data__1f5rh table-data z-pl-20">$41.35</td><td class="table_data__1f5rh table-data z-pl-20">872</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Minnesota</td><td class="table_data__1f5rh table-data z-pl-20">$85,967</td><td class="table_data__1f5rh table-data z-pl-20">$41.33</td><td class="table_data__1f5rh table-data z-pl-20">947</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Mississippi</td><td class="table_data__1f5rh table-data z-pl-20">$78,315</td><td class="table_data__1f5rh table-data z-pl-20">$37.65</td><td class="table_data__1f5rh table-data z-pl-20">160</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Missouri</td><td class="table_data__1f5rh table-data z-pl-20">$80,712</td><td class="table_data__1f5rh table-data z-pl-20">$38.80</td><td class="table_data__1f5rh table-data z-pl-20">868</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Montana</td><td class="table_data__1f5rh table-data z-pl-20">$73,626</td><td class="table_data__1f5rh table-data z-pl-20">$35.40</td><td class="table_data__1f5rh table-data z-pl-20">197</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Nebraska</td><td class="table_data__1f5rh table-data z-pl-20">$75,594</td><td class="table_data__1f5rh table-data z-pl-20">$36.34</td><td class="table_data__1f5rh table-data z-pl-20">284</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Nevada</td><td class="table_data__1f5rh table-data z-pl-20">$93,869</td><td class="table_data__1f5rh table-data z-pl-20">$45.13</td><td class="table_data__1f5rh table-data z-pl-20">278</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">New Hampshire</td><td class="table_data__1f5rh table-data z-pl-20">$86,179</td><td class="table_data__1f5rh table-data z-pl-20">$41.43</td><td class="table_data__1f5rh table-data z-pl-20">292</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">New Jersey</td><td class="table_data__1f5rh table-data z-pl-20">$94,526</td><td class="table_data__1f5rh table-data z-pl-20">$45.45</td><td class="table_data__1f5rh table-data z-pl-20">1,845</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">New Mexico</td><td class="table_data__1f5rh table-data z-pl-20">$79,613</td><td class="table_data__1f5rh table-data z-pl-20">$38.28</td><td class="table_data__1f5rh table-data z-pl-20">311</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">New York</td><td class="table_data__1f5rh table-data z-pl-20">$102,130</td><td class="table_data__1f5rh table-data z-pl-20">$49.10</td><td class="table_data__1f5rh table-data z-pl-20">2,735</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">North Carolina</td><td class="table_data__1f5rh table-data z-pl-20">$83,303</td><td class="table_data__1f5rh table-data z-pl-20">$40.05</td><td class="table_data__1f5rh table-data z-pl-20">1,788</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">North Dakota</td><td class="table_data__1f5rh table-data z-pl-20">$76,242</td><td class="table_data__1f5rh table-data z-pl-20">$36.65</td><td class="table_data__1f5rh table-data z-pl-20">155</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Ohio</td><td class="table_data__1f5rh table-data z-pl-20">$87,588</td><td class="table_data__1f5rh table-data z-pl-20">$42.11</td><td class="table_data__1f5rh table-data z-pl-20">1,164</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Oklahoma</td><td class="table_data__1f5rh table-data z-pl-20">$77,146</td><td class="table_data__1f5rh table-data z-pl-20">$37.09</td><td class="table_data__1f5rh table-data z-pl-20">236</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Oregon</td><td class="table_data__1f5rh table-data z-pl-20">$101,355</td><td class="table_data__1f5rh table-data z-pl-20">$48.73</td><td class="table_data__1f5rh table-data z-pl-20">596</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Pennsylvania</td><td class="table_data__1f5rh table-data z-pl-20">$89,722</td><td class="table_data__1f5rh table-data z-pl-20">$43.14</td><td class="table_data__1f5rh table-data z-pl-20">1,804</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Rhode Island</td><td class="table_data__1f5rh table-data z-pl-20">$88,971</td><td class="table_data__1f5rh table-data z-pl-20">$42.77</td><td class="table_data__1f5rh table-data z-pl-20">180</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">South Carolina</td><td class="table_data__1f5rh table-data z-pl-20">$77,818</td><td class="table_data__1f5rh table-data z-pl-20">$37.41</td><td class="table_data__1f5rh table-data z-pl-20">423</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">South Dakota</td><td class="table_data__1f5rh table-data z-pl-20">$75,861</td><td class="table_data__1f5rh table-data z-pl-20">$36.47</td><td class="table_data__1f5rh table-data z-pl-20">184</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Tennessee</td><td class="table_data__1f5rh table-data z-pl-20">$83,521</td><td class="table_data__1f5rh table-data z-pl-20">$40.15</td><td class="table_data__1f5rh table-data z-pl-20">551</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Texas</td><td class="table_data__1f5rh table-data z-pl-20">$87,577</td><td class="table_data__1f5rh table-data z-pl-20">$42.10</td><td class="table_data__1f5rh table-data z-pl-20">2,563</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Utah</td><td class="table_data__1f5rh table-data z-pl-20">$84,087</td><td class="table_data__1f5rh table-data z-pl-20">$40.43</td><td class="table_data__1f5rh table-data z-pl-20">510</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Vermont</td><td class="table_data__1f5rh table-data z-pl-20">$78,398</td><td class="table_data__1f5rh table-data z-pl-20">$37.69</td><td class="table_data__1f5rh table-data z-pl-20">123</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Virginia</td><td class="table_data__1f5rh table-data z-pl-20">$88,512</td><td class="table_data__1f5rh table-data z-pl-20">$42.55</td><td class="table_data__1f5rh table-data z-pl-20">1,789</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Washington</td><td class="table_data__1f5rh table-data z-pl-20">$119,916</td><td class="table_data__1f5rh table-data z-pl-20">$57.65</td><td class="table_data__1f5rh table-data z-pl-20">1,222</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">West Virginia</td><td class="table_data__1f5rh table-data z-pl-20">$86,216</td><td class="table_data__1f5rh table-data z-pl-20">$41.45</td><td class="table_data__1f5rh table-data z-pl-20">176</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Wisconsin</td><td class="table_data__1f5rh table-data z-pl-20">$82,510</td><td class="table_data__1f5rh table-data z-pl-20">$39.67</td><td class="table_data__1f5rh table-data z-pl-20">679</td></tr><tr class="table_bodyRow__10Zw0 table-body-row"><td class="table_data__1f5rh table-data z-pl-20" style="width: 33%;">Wyoming</td><td class="table_data__1f5rh table-data z-pl-20">$73,335</td><td class="table_data__1f5rh table-data z-pl-20">$35.26</td><td class="table_data__1f5rh table-data z-pl-20">92</td></tr></tbody></table>
'''
state_list = pd.read_html(string2)

# %%
state_df = pd.concat(state_list)
state_df
# Out:
#                    State Avg. Salary Hourly Rate  Job Count
# 0                Alabama     $77,743      $37.38        390
# 1                 Alaska     $84,755      $40.75        148
# 2                Arizona     $88,333      $42.47        831
# 3               Arkansas     $82,909      $39.86        266
# 4             California    $126,682      $60.90       3874
# 5               Colorado     $82,112      $39.48        877
# 6            Connecticut     $92,237      $44.34        678
# 7               Delaware     $95,563      $45.94        241
# 8   District of Columbia     $92,648      $44.54        504
# 9                Florida     $76,936      $36.99       1801
# 10               Georgia     $81,997      $39.42       1275
# 11                Hawaii     $85,453      $41.08        160
# 12                 Idaho     $88,982      $42.78        249
# 13              Illinois     $85,726      $41.21       2023
# 14               Indiana     $79,391      $38.17        712
# 15                  Iowa     $78,285      $37.64        427
# 16                Kansas     $78,037      $37.52        388
# 17              Kentucky     $78,352      $37.67        396
# 18             Louisiana     $80,084      $38.50        315
# 19                 Maine     $78,384      $37.68        196
# 20              Maryland     $90,523      $43.52       1516
# 21         Massachusetts     $94,404      $45.39       1684
# 22              Michigan     $86,008      $41.35        872
# 23             Minnesota     $85,967      $41.33        947
# 24           Mississippi     $78,315      $37.65        160
# 25              Missouri     $80,712      $38.80        868
# 26               Montana     $73,626      $35.40        197
# 27              Nebraska     $75,594      $36.34        284
# 28                Nevada     $93,869      $45.13        278
# 29         New Hampshire     $86,179      $41.43        292
# 30            New Jersey     $94,526      $45.45       1845
# 31            New Mexico     $79,613      $38.28        311
# 32              New York    $102,130      $49.10       2735
# 33        North Carolina     $83,303      $40.05       1788
# 34          North Dakota     $76,242      $36.65        155
# 35                  Ohio     $87,588      $42.11       1164
# 36              Oklahoma     $77,146      $37.09        236
# 37                Oregon    $101,355      $48.73        596
# 38          Pennsylvania     $89,722      $43.14       1804
# 39          Rhode Island     $88,971      $42.77        180
# 40        South Carolina     $77,818      $37.41        423
# 41          South Dakota     $75,861      $36.47        184
# 42             Tennessee     $83,521      $40.15        551
# 43                 Texas     $87,577      $42.10       2563
# 44                  Utah     $84,087      $40.43        510
# 45               Vermont     $78,398      $37.69        123
# 46              Virginia     $88,512      $42.55       1789
# 47            Washington    $119,916      $57.65       1222
# 48         West Virginia     $86,216      $41.45        176
# 49             Wisconsin     $82,510      $39.67        679
# 50               Wyoming     $73,335      $35.26         92

# %% [markdown]
# ## Perform data transformation and/or cleansing steps

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 1:
# Separate out the City and State data from the "City" column in city_df. Store the resulting values in 'city' and 'state' columns within the DataFrame.This step is required so the data can be merged based on 'state' in a later step.

# %%
city_df[['city','state']] = city_df['City'].str.split(",", n =1, expand = True)

# %%
city_df.head(10)
# Out:
#               City Avg. Salary Hourly Rate         city state
# 0    Arlington, VA     $90,649      $43.58    Arlington    VA
# 1       Austin, TX     $88,720      $42.65       Austin    TX
# 2  Bentonville, AR     $82,474      $39.65  Bentonville    AR
# 3       Boston, MA     $94,202      $45.29       Boston    MA
# 4      Chicago, IL     $86,137      $41.41      Chicago    IL
# 5     Columbus, GA     $82,140      $39.49     Columbus    GA
# 6     Columbus, OH     $86,664      $41.67     Columbus    OH
# 7       Denver, CO     $81,990      $39.42       Denver    CO
# 8      Detroit, MI     $86,286      $41.48      Detroit    MI
# 9  Jersey City, NJ     $94,662      $45.51  Jersey City    NJ

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 2:
# Strip the whitespace in the 'city' and 'state' columns from city_df. This will help with the merging of the two DataFrames.

# %%
city_df['city'] = city_df['city'].str.strip()
city_df['state'] = city_df['state'].str.strip()

# %%
city_df.head(5)
# Out:
#               City Avg. Salary Hourly Rate         city state
# 0    Arlington, VA     $90,649      $43.58    Arlington    VA
# 1       Austin, TX     $88,720      $42.65       Austin    TX
# 2  Bentonville, AR     $82,474      $39.65  Bentonville    AR
# 3       Boston, MA     $94,202      $45.29       Boston    MA
# 4      Chicago, IL     $86,137      $41.41      Chicago    IL

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 3:
# Remove the 'City' column from city_df. Rearrange the columns so that 'city' and 'state' are the first two columns of the DataFrame.

# %%
city_df.drop(['City'], axis = 1, inplace = True)

# %%
city_df = city_df[['city','state','Avg. Salary','Hourly Rate']]
city_df.head(5)
# Out:
#           city state Avg. Salary Hourly Rate
# 0    Arlington    VA     $90,649      $43.58
# 1       Austin    TX     $88,720      $42.65
# 2  Bentonville    AR     $82,474      $39.65
# 3       Boston    MA     $94,202      $45.29
# 4      Chicago    IL     $86,137      $41.41

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 4:
# Rename the column names so they are easier to distinguish for merging the data. Another reason to rename is the spaces in the names for the columns 'Avg. Salary' and 'Hourly Rate'.

# %%
column_names1 = ['city','state','average_salary','hourly_rate']

city_df.columns = column_names1
city_df.head(5)
# Out:
#           city state average_salary hourly_rate
# 0    Arlington    VA        $90,649      $43.58
# 1       Austin    TX        $88,720      $42.65
# 2  Bentonville    AR        $82,474      $39.65
# 3       Boston    MA        $94,202      $45.29
# 4      Chicago    IL        $86,137      $41.41

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 5:
# Remove the dollar sign in the 'average_salary' and 'hourly_rate' columns in city_df. Then, assign the correct data type for both of these columns.

# %%
city_df['average_salary'] = city_df['average_salary'].replace({'\$':''}, regex = True)
city_df['hourly_rate'] = city_df['hourly_rate'].replace({'\$':''}, regex = True)

# %%
city_df.head(5)
# Out:
#           city state average_salary hourly_rate
# 0    Arlington    VA         90,649       43.58
# 1       Austin    TX         88,720       42.65
# 2  Bentonville    AR         82,474       39.65
# 3       Boston    MA         94,202       45.29
# 4      Chicago    IL         86,137       41.41

# %%
city_df['average_salary'] = pd.Series(city_df['average_salary']).str.replace(',','').astype(int)

# %%
city_df['hourly_rate'] = pd.Series(city_df['hourly_rate']).astype(float)

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            20 non-null     object
#  1   state           20 non-null     object
#  2   average_salary  20 non-null     int32
#  3   hourly_rate     20 non-null     float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 688.0+ bytes

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 6:
# Rename the columns in state_df. This will help eliminate spaces in the column names.

# %%
column_names2 = ['state_name','average_salary','hourly_rate','job_count']

state_df.columns = column_names2
state_df.head(5)
# Out:
#    state_name average_salary hourly_rate  job_count
# 0     Alabama        $77,743      $37.38        390
# 1      Alaska        $84,755      $40.75        148
# 2     Arizona        $88,333      $42.47        831
# 3    Arkansas        $82,909      $39.86        266
# 4  California       $126,682      $60.90       3874

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 6:
# Remove the dollar sign in the 'average_salary' and 'hourly_rate' columns for state_df. Then, assign the correct data type for both of these columns.

# %%
state_df['average_salary'] = state_df['average_salary'].replace({'\$':''}, regex = True)
state_df['hourly_rate'] = state_df['hourly_rate'].replace({'\$':''}, regex = True)

# %%
state_df['average_salary'] = pd.Series(state_df['average_salary']).str.replace(',','').astype(int)

# %%
state_df['hourly_rate'] = pd.Series(state_df['hourly_rate']).astype(float)

# %%
state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state_name      51 non-null     object
#  1   average_salary  51 non-null     int32
#  2   hourly_rate     51 non-null     float64
#  3   job_count       51 non-null     int64
# dtypes: float64(1), int32(1), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
state_df.head(5)
# Out:
#    state_name  average_salary  hourly_rate  job_count
# 0     Alabama           77743        37.38        390
# 1      Alaska           84755        40.75        148
# 2     Arizona           88333        42.47        831
# 3    Arkansas           82909        39.86        266
# 4  California          126682        60.90       3874

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 7:
# Create a dictionary of state as key and state abbreviations as value. Write the abbreviation values as a column 'state'
#  in state_df. This will be used to help with the merge step. Use the map() method to create the additional column.

# %%
state_ranks = pd.read_csv("2021_state_ranks.csv")

# %%
state_dict = dict(zip(state_ranks['state_name'],state_ranks['state']))
state_dict
# Out:
# {'Washington': 'WA',
#  'Minnesota': 'MN',
#  'Utah': 'UT',
#  'New Hampshire': 'NH',
#  'Idaho': 'ID',
#  'Nebraska': 'NE',
#  'Virginia': 'VA',
#  'Wisconsin': 'WI',
#  'Massachusetts': 'MA',
#  'Florida': 'FL',
#  'Vermont': 'VT',
#  'Iowa': 'IA',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'South Dakota': 'SD',
#  'Colorado': 'CO',
#  'Maryland': 'MD',
#  'Georgia': 'GA',
#  'New Jersey': 'NJ',
#  'Connecticut': 'CT',
#  'New York': 'NY',
#  'Oregon': 'OR',
#  'Delaware': 'DE',
#  'California': 'CA',
#  'Hawaii': 'HI',
#  'Kansas': 'KS',
#  'Maine': 'ME',
#  'Missouri': 'MO',
#  'Tennessee': 'TN',
#  'Illinois': 'IL',
#  'Texas': 'TX',
#  'Indiana': 'IN',
#  'Montana': 'MT',
#  'Rhode Island': 'RI',
#  'Wyoming': 'WY',
#  'Ohio': 'OH',
#  'Nevada': 'NV',
#  'Michigan': 'MI',
#  'Arizona': 'AZ',
#  'Pennsylvania': 'PA',
#  'Kentucky': 'KY',
#  'South Carolina': 'SC',
#  'Oklahoma': 'OK',
#  'Arkansas': 'AK',
#  'Alaska': 'AK',
#  'Alabama': 'AL',
#  'West Virginia': 'WV',
#  'New Mexico': 'NM',
#  'Mississippi': 'MS',
#  'Louisiana': 'LA'}

# %%
state_df['state'] = state_df['state_name'].map(state_dict)

# %%
state_df.head(10)
# Out:
#              state_name  average_salary  hourly_rate  job_count state
# 0               Alabama           77743        37.38        390    AL
# 1                Alaska           84755        40.75        148    AK
# 2               Arizona           88333        42.47        831    AZ
# 3              Arkansas           82909        39.86        266    AK
# 4            California          126682        60.90       3874    CA
# 5              Colorado           82112        39.48        877    CO
# 6           Connecticut           92237        44.34        678    CT
# 7              Delaware           95563        45.94        241    DE
# 8  District of Columbia           92648        44.54        504   NaN
# 9               Florida           76936        36.99       1801    FL

# %% [markdown]
# ### Data Transformation and/or Cleansing Step 8:
# Merge the city_df and state_df DataFrames together based on 'state'.

# %%
city_df.set_index(['state'], inplace = True)
city_df.head(10)
# Out:
#               city  average_salary  hourly_rate
# state
# VA       Arlington           90649        43.58
# TX          Austin           88720        42.65
# AR     Bentonville           82474        39.65
# MA          Boston           94202        45.29
# IL         Chicago           86137        41.41
# GA        Columbus           82140        39.49
# OH        Columbus           86664        41.67
# CO          Denver           81990        39.42
# MI         Detroit           86286        41.48
# NJ     Jersey City           94662        45.51

# %%
state_df.set_index(['state'], inplace = True)
state_df.head(10)
# Out:
#                  state_name  average_salary  hourly_rate  job_count
# state
# AL                  Alabama           77743        37.38        390
# AK                   Alaska           84755        40.75        148
# AZ                  Arizona           88333        42.47        831
# AK                 Arkansas           82909        39.86        266
# CA               California          126682        60.90       3874
# CO                 Colorado           82112        39.48        877
# CT              Connecticut           92237        44.34        678
# DE                 Delaware           95563        45.94        241
# NaN    District of Columbia           92648        44.54        504
# FL                  Florida           76936        36.99       1801

# %%
final_df = pd.merge(state_df, city_df, on='state', how='left')
final_df
# Out:
#                  state_name  average_salary_x  hourly_rate_x  job_count  \
# state
# AL                  Alabama             77743          37.38        390
# AK                   Alaska             84755          40.75        148
# AZ                  Arizona             88333          42.47        831
# AK                 Arkansas             82909          39.86        266
# CA               California            126682          60.90       3874
# CO                 Colorado             82112          39.48        877
# CT              Connecticut             92237          44.34        678
# DE                 Delaware             95563          45.94        241
# NaN    District of Columbia             92648          44.54        504
# FL                  Florida             76936          36.99       1801
# GA                  Georgia             81997          39.42       1275
# HI                   Hawaii             85453          41.08        160
# ID                    Idaho             88982          42.78        249
# IL                 Illinois             85726          41.21       2023
# IN                  Indiana             79391          38.17        712
# IA                     Iowa             78285          37.64        427
# KS                   Kansas             78037          37.52        388
# KY                 Kentucky             78352          37.67        396
# LA                Louisiana             80084          38.50        315
# ME                    Maine             78384          37.68        196
# MD                 Maryland             90523          43.52       1516
# MA            Massachusetts             94404          45.39       1684
# MI                 Michigan             86008          41.35        872
# MN                Minnesota             85967          41.33        947
# MS              Mississippi             78315          37.65        160
# MO                 Missouri             80712          38.80        868
# MT                  Montana             73626          35.40        197
# NE                 Nebraska             75594          36.34        284
# NV                   Nevada             93869          45.13        278
# NH            New Hampshire             86179          41.43        292
# NJ               New Jersey             94526          45.45       1845
# NM               New Mexico             79613          38.28        311
# NY                 New York            102130          49.10       2735
# NC           North Carolina             83303          40.05       1788
# ND             North Dakota             76242          36.65        155
# OH                     Ohio             87588          42.11       1164
# OK                 Oklahoma             77146          37.09        236
# OR                   Oregon            101355          48.73        596
# PA             Pennsylvania             89722          43.14       1804
# RI             Rhode Island             88971          42.77        180
# SC           South Carolina             77818          37.41        423
# SD             South Dakota             75861          36.47        184
# TN                Tennessee             83521          40.15        551
# TX                    Texas             87577          42.10       2563
# UT                     Utah             84087          40.43        510
# VT                  Vermont             78398          37.69        123
# VA                 Virginia             88512          42.55       1789
# WA               Washington            119916          57.65       1222
# WV            West Virginia             86216          41.45        176
# WI                Wisconsin             82510          39.67        679
# WY                  Wyoming             73335          35.26         92
#
#                 city  average_salary_y  hourly_rate_y
# state
# AL               NaN               NaN            NaN
# AK               NaN               NaN            NaN
# AZ           Phoenix           88469.0          42.53
# AK               NaN               NaN            NaN
# CA     San Francisco          138170.0          66.43
# CO            Denver           81990.0          39.42
# CT               NaN               NaN            NaN
# DE               NaN               NaN            NaN
# NaN              NaN               NaN            NaN
# FL               NaN               NaN            NaN
# GA          Columbus           82140.0          39.49
# HI               NaN               NaN            NaN
# ID               NaN               NaN            NaN
# IL           Chicago           86137.0          41.41
# IN               NaN               NaN            NaN
# IA               NaN               NaN            NaN
# KS               NaN               NaN            NaN
# KY               NaN               NaN            NaN
# LA               NaN               NaN            NaN
# ME               NaN               NaN            NaN
# MD               NaN               NaN            NaN
# MA            Boston           94202.0          45.29
# MI           Detroit           86286.0          41.48
# MN       Minneapolis           86134.0          41.41
# MS               NaN               NaN            NaN
# MO       Saint Louis           81195.0          39.04
# MT               NaN               NaN            NaN
# NE               NaN               NaN            NaN
# NV               NaN               NaN            NaN
# NH               NaN               NaN            NaN
# NJ       Jersey City           94662.0          45.51
# NM               NaN               NaN            NaN
# NY          New York          102427.0          49.24
# NC           Raleigh           83965.0          40.37
# ND               NaN               NaN            NaN
# OH          Columbus           86664.0          41.67
# OK               NaN               NaN            NaN
# OR               NaN               NaN            NaN
# PA      Philadelphia           90231.0          43.38
# RI               NaN               NaN            NaN
# SC               NaN               NaN            NaN
# SD               NaN               NaN            NaN
# TN               NaN               NaN            NaN
# TX            Austin           88720.0          42.65
# UT               NaN               NaN            NaN
# VT               NaN               NaN            NaN
# VA         Arlington           90649.0          43.58
# WA           Seattle          122139.0          58.72
# WV               NaN               NaN            NaN
# WI           Madison           81874.0          39.36
# WY               NaN               NaN            NaN
